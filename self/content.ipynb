# %%
import pandas as pd

# Define the path to your CSV file
csv_file_path = r"C:\Users\shiva\Downloads\netflix-report\CONTENT_INTERACTION\ViewingActivity.csv"

# Define the user to filter by
target_user = "Shivambu"

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Print the entire DataFrame to see the data (optional)
print(df)

# Filter the DataFrame by the target user
user_data = df[df['Profile Name'] == target_user]

# Select specific columns
selected_columns = user_data[['Profile Name', 'Start Time', 'Duration', 'Title', 'Device Type', 'Bookmark', 'Latest Bookmark', 'Country']]

# Print the extracted data
print(selected_columns)
# Out:
#      Profile Name           Start Time  Duration Attributes  \
# 0        Himanshu  2022-08-30 17:46:49  00:00:06        NaN
# 1        Himanshu  2022-08-30 16:35:49  00:05:31        NaN
# 2        Himanshu  2022-08-30 15:57:58  00:00:13        NaN
# 3        Himanshu  2022-08-30 15:47:26  00:00:19        NaN
# 4        Himanshu  2022-08-30 15:23:35  00:00:01        NaN
# ...           ...                  ...       ...        ...
# 4675     Shivangi  2022-01-20 18:55:28  00:00:03        NaN
# 4676     Shivangi  2022-01-20 18:55:08  00:00:04        NaN
# 4677     Shivangi  2022-01-20 18:09:58  00:41:23        NaN
# 4678     Shivangi  2022-01-20 18:08:00  00:00:30        NaN
# 4679     Shivangi  2022-01-20 16:54:30  00:06:40        NaN
#
#                                                   Title  \
# 0              Who Rules the World: Season 1: Episode 1
# 1              Who Rules the World: Season 1: Episode 1
# 2              Who Rules the World: Season 1: Episode 1
# ...

# %%
import pandas as pd

# Define the path to your CSV file
csv_file_path = r"C:\Users\shiva\Downloads\netflix-report\CONTENT_INTERACTION\ViewingActivity.csv"

# Define the path for the output file
output_file_path = r"C:\Users\shiva\Downloads\netflix-report\CONTENT_INTERACTION\S_Watch_History.csv"

# Define the user to filter by
target_user = "Shivambu"

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Filter the DataFrame by the target user
user_data = df[df['Profile Name'] == target_user]

# Select the 'Title' column
watch_history = user_data[['Title']]

# Save the extracted titles to a new CSV file
watch_history.to_csv(output_file_path, index=False)

print(f"Watch history for {target_user} has been saved to {output_file_path}")
# Out:
# Watch history for Shivambu has been saved to C:\Users\shiva\Downloads\netflix-report\CONTENT_INTERACTION\S_Watch_History.csv
